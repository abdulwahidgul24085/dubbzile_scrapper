# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
from ast import literal_eval
from pprint import pprint
import pandas as pd
import time

# %%
driver = webdriver.Firefox()
driver.get(r'https://dubai.dubizzle.com/en/property-for-rent/residential/apartmentflat/in/discovery-gardens/190/')

# %%
total_listing = []
exist = False
while exist == False:
    try:
        driver.find_element_by_class_name('no-results-holder')
        print('No result page end of listing')
        exist = True
    except Exception as e:
        #     print('Keep Scarping')
        page = bs(driver.page_source, 'html.parser')
        for listing in page.find_all('a',class_='listing-link'):
            content = literal_eval(listing.script.text)
            total_listing.append({
                'name':content['']['name'],
                'price':content['']['offers']['price'],
                'alt_price':listing.find('div', class_="details").find('div', class_='price').text,
                'url':content['']['url'],
                'long':content['geo']['latitude'],
                'lat':content['geo']['longitude'],
                'floor_size':content['floorSize'],
#                 'alt_floor_size':listing.find('div', class_='details').find_all('span',class_='float-left')[-1].text
            })
        driver.find_element_by_css_selector(r'a.sc-tilXH:nth-child(3)').click()
        print(len(total_listing))
        time.sleep(5)
#         exist = True
# Out:
# 30
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-30-c8e27a91b27f> in <module>
#       4     try:
# ----> 5         driver.find_element_by_class_name('no-results-holder')
#       6         print('No result page end of listing')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: Unable to locate element: .no-results-holder
#
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-c8e27a91b27f> in <module>
#      19                 'lat':content['geo']['longitude'],
#      20                 'floor_size':content['floorSize'],
# ---> 21                 'alt_floor_size':listing.find('div', class_='details').find_all('span',class_='float-left')[-1].text
#      22             })
#      23         driver.find_element_by_css_selector(r'a.sc-tilXH:nth-child(3)').click()
#
# IndexError: list index out of range

# %%
results = pd.DataFrame(total_listing)
results
# Out:
#    alt_floor_size     alt_price  floor_size        lat       long  \
# 0       680 SqFt    AED 30,000          680  25.038964  55.145042
# 1       900 SqFt    AED 50,000          900  25.038964  55.145042
# 2       550 SqFt    AED 28,000          550  25.038964  55.145042
# 3       980 SqFt    AED 55,000          980  25.038964  55.145042
# 4       968 SqFt    AED 50,000          968  25.033350  55.150016
# 5       650 SqFt    AED 29,000          650  25.039000  55.145000
# 6       600 SqFt    AED 34,000          600  25.038964  55.145042
# 7       525 SqFt    AED 36,000          525  25.038964  55.145042
# 8       650 SqFt    AED 36,000          650  25.033350  55.150016
# 9       480 SqFt    AED 28,000          480  25.038964  55.145042
# 10      480 SqFt    AED 30,000          480  25.045380  55.137360
# 11     1150 SqFt    AED 52,000         1150  25.039000  55.145000
# 12      588 SqFt    AED 34,000          588  25.039000  55.145000
# 13      650 SqFt    AED 29,000          650  25.038964  55.145042
# 14      650 SqFt    AED 35,000          650  25.038964  55.145042
# 15     1245 SqFt    AED 42,000         1245  25.038964  55.145042
# 16      493 SqFt    AED 28,000          493  25.039000  55.145000
# 17      900 SqFt    AED 39,000          900  25.039000  55.145000
# 18      900 SqFt    AED 40,000          900  25.042094  55.141201
# 19     1250 SqFt    AED 58,000         1250  25.038964  55.145042
# 20     1200 SqFt    AED 54,000         1200  25.038964  55.145042
# 21     1250 SqFt    AED 43,000         1250  25.044519  55.137291
# 22      650 SqFt    AED 38,000          650  25.044519  55.137291
# 23      650 SqFt    AED 28,000          650  25.044519  55.137291
# 24      480 SqFt    AED 30,000          480  25.045380  55.137360
# 25      520 SqFt    AED 34,000          520  25.049230  55.131260
# 26     1100 SqFt    AED 50,000         1100  25.049230  55.131260
# 27      650 SqFt    AED 30,000          650  25.038964  55.145042
# 28     1200 SqFt    AED 40,000         1200  25.038964  55.145042
# 29     1200 SqFt    AED 44,000         1200  25.038964  55.145042
#
#                                                  name  price  \
# 0   6 CHQS II 13 MONTHS II STUDIO WITH CLOSED KITC...  30000
# 1   NEW OFFER 2 MONTHS FREE!! CHILLER FREE WITH BA...  50000
# 2   28k in 4 cheques | Ready to move Studio | Avai...  28000
# 3              Furnished | 1 bedroom | close to metro  55000
# 4      V-Type, AC Free, 13 Month, 2 Balconies, 6 CHQs  50000
# 5   Large Studio With 08 Wardrobes For Rent  Ready...  29000
# 6   WOW! Studio Fully Furnished Studio with Balcon...  34000
# 7   WOW Monthly Payment 12 CHQS STUDIO Chiller Fre...  36000
# 8   Upgraded Large Studio + Storage Room I Garden ...  36000
# 9   Studio for rent without balcony B#100 ( 5% Age...  28000
# 10          Ready to move, Studio in Discovery Garden  30000
# 11  STREET 2 II CHILLER FREE II LARGEST BEAUTIFUL ...  52000
# 12  13 MONTHS II CHILLER FREE II BEAUTIFUL STUDIOS...  34000
# 13  9 CUPBOARDS STUDIO WITH 18 TILES AVAILABLE FOR...  29000
# 14  CHILLER FREE II L SHAPE STUDIO WITH STORE ROOM...  35000
# 15  SPECIOUS 1 BEDROOM APT, U-TYPE, MED CLUSTER, N...  42000
# 16                      STUDIO APARTMENT WITH BALCONY  28000
